# %%
import pandas as pd

# %%
country_csv = pd.read_csv('rawdata\csv\country.csv')
print(country_csv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 country_csv = pd.read_csv('rawdata\csv\country.csv')
#       2 print(country_csv)
#
# File c:\Users\ashpi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.DataFrame(country_csv)
#copying dataframe
df1 = df.copy()
print(df1)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# #Removing missing values

# %%
#use mean for numberic columns
print(df1['Age'].dtype)
print(df1['Age'])
# Out:
# float64
# 0    44.0
# 1    27.0
# 2    30.0
# 3    38.0
# 4    40.0
# 5    35.0
# 6     NaN
# 7    48.0
# 8    50.0
# 9    37.0
# Name: Age, dtype: float64

# %% [markdown]
# #fiiling with mean values

# %%
df1['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df1
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0       Yes
# 1    Spain  27.000000  48000.0       Yes
# 2      NaN  30.000000  54000.0       NaN
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5   France  35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No
# 9   France  37.000000  67000.0       Yes

# %% [markdown]
# Updating df1, salary with most fequeent technique

# %% [markdown]
# df1['Salary'].isnull().sum()     ## gives count of null values

# %% [markdown]
# #below lines are to convert CSV dataframe to json format

# %%
df.to_json('rawdata\json\country.json', orient='records', lines=True)

# %%
df1['Salary'].fillna(df['Salary'].mode()[0])  ## gives most frequent value
# Out:
# 0    72000.0
# 1    48000.0
# 2    54000.0
# 3    61000.0
# 4    48000.0
# 5    58000.0
# 6    52000.0
# 7    79000.0
# 8    83000.0
# 9    67000.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Using [AB_NYC_2029](rawdata/csv/AB_NYC_2019.csv)

# %%
df_ab_nyc = pd.read_csv('rawdata/csv/AB_NYC_2019.csv')

# %%
df_ab_nyc.duplicated().sum()         # to check how many duplicates are there
# Out:
# np.int64(11)

# %%
df_ab_nyc[df_ab_nyc.duplicated()]  #keep = false  # to see the duplicate rows
                                #keep = 'last'  # to keep last duplicate
                                #keep = 'first' # to keep first duplicate
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df_ab_nyc.drop_duplicates(keep='first', inplace=True)  # drop duplicates from dataframe

# %%
df_ab_nyc.duplicated().sum()  # to check how many duplicates are there after removing duplicates
# Out:
# np.int64(0)

# %%
df_ab_nyc.duplicated('name').sum()  # to check duplicates based on specific column
# Out:
# np.int64(998)

# %%
# now check if they really exit
df_ab_nyc[df_ab_nyc.duplicated('name')].head(10)  # to see the duplicate rows based on specific column
# Out:
#          id                                name  host_id            host_name  \
# 330   81739   Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
# 339   84010                Superior @ Box House   417504  The Box House Hotel
# 580  219818  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692         Keera (Jena)
# 661  250537                 The Lenox in Harlem  1313306               Yvette
# 669  253471    Loft Suite @ The Box House Hotel   417504  The Box House Hotel
# 670  253475    Loft Suite @ The Box House Hotel   417504  The Box House Hotel
# 674  253800        Loft Suite @ Box House Hotel   417504  The Box House Hotel
# 675  253803    Loft Suite @ The Box House Hotel   417504  The Box House Hotel
# 676  253806    Loft Suite @ The Box House Hotel   417504  The Box House Hotel
# 677  253811    Loft Suite @ The Box House Hotel   417504  The Box House Hotel
#
#     neighbourhood_group    neighbourhood  latitude  longitude  \
# ...

# %%
df_ab_nyc.drop_duplicates(subset='name', keep='first', inplace=True)

# %%
cities = ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix','Los Angeles', 'Chicago']
rankings = [1, 2, 3, 4, 5,6,7]
scores = [9.8, 9.5, 9.2, 8.7, 8.5, 8.2, 8.1]

data = {'City': cities, 'Ranking': rankings, 'Score': scores}

df_city_ranking = pd.DataFrame(data)

# %% [markdown]
# Outlier
#
# mean, variance and standard deviation (sq root of variance) impacted due to outlier
#
# so if you want to fill data, without outlier handling use median and mode which are lease affected
