# %%
#Univariate non graphical analysis

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/11.0 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.0 MB 1.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.0 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.0 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.0 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.8/11.0 MB 1.1 MB/s eta 0:00:09
#    ------- -------------------------------- 2.1/11.0 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.0 MB 1.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.9/11.0 MB 1.3 MB/s eta 0:00:07
# ...

# %%
import pandas as pd

# %%
pd.read_csv(r'C:\Users\ashpi\git-projects\dataScience\DataEngMain\projects\basics\rawdata\csv\AB_NYC_2019.csv')
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
try:
    data = pd.read_csv(r'C:\Users\ashpi\git-projects\dataScience\DataEngMain\projects\basics\rawdata\csv\AB_NYC_2019.csv')
except FileNotFoundError:
    print("File not found. Please check the file path.")
    print("Tip: To use a relative path, place 'AB_NYC_2019.csv' in your working directory and use:")
    print("    pd.read_csv('AB_NYC_2019.csv')")
except OSError as e:
    print(f"OS error check file path: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48906 entries, 0 to 48905
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48906 non-null  int64
#  1   name                            48890 non-null  object
#  2   host_id                         48906 non-null  int64
#  3   host_name                       48885 non-null  object
#  4   neighbourhood_group             48906 non-null  object
#  5   neighbourhood                   48906 non-null  object
#  6   latitude                        48906 non-null  float64
#  7   longitude                       48906 non-null  float64
#  8   room_type                       48906 non-null  object
#  9   price                           48906 non-null  int64
#  10  minimum_nights                  48906 non-null  int64
#  11  number_of_reviews               48906 non-null  int64
# ...

# %%
df.describe()      # for numerical columns, df.describe(include='all') for all columns
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890600e+04  4.890600e+04  48906.000000  48906.000000  48906.000000
# mean   1.901287e+07  6.760480e+07     40.728952    -73.952175    152.711324
# std    1.098557e+07  7.860866e+07      0.054529      0.046154    240.128713
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.464662e+06  7.809567e+06     40.690100    -73.983080     69.000000
# 50%    1.967545e+07  3.078463e+07     40.723080    -73.955685    106.000000
# 75%    2.915085e+07  1.074344e+08     40.763120    -73.936283    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48906.000000       48906.000000       38854.000000
# mean         7.031612          23.300454           1.373151
# std         20.512489          44.607175           1.680270
# ...

# %%
df.describe(include='all')  # for all columns
# Out:
#                   id            name       host_id host_name  \
# count   4.890600e+04           48890  4.890600e+04     48885
# unique           NaN           47896           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901287e+07             NaN  6.760480e+07       NaN
# std     1.098557e+07             NaN  7.860866e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.464662e+06             NaN  7.809567e+06       NaN
# 50%     1.967545e+07             NaN  3.078463e+07       NaN
# 75%     2.915085e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48906         48906  48906.000000  48906.000000
# unique                   5           221           NaN           NaN
# ...

# %%
df.head()     # First 5 rows

df.tail()     # Last 5 rows

df.sample(5)  # Random sample of 5 rows

df.columns    # to get all column names

df.shape      # to get now of rowss and columns
# Out:
# (48906, 16)

# %% [markdown]
# #first get some insight of the data before doing the analysis
# #use above methods to get insight

# %%
df['room_type']
# Out:
# 0           Private room
# 1        Entire home/apt
# 2           Private room
# 3        Entire home/apt
# 4        Entire home/apt
#               ...
# 48901       Private room
# 48902       Private room
# 48903       Private room
# 48904    Entire home/apt
# 48905    Entire home/apt
# Name: room_type, Length: 48906, dtype: object

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25414
# Private room       22332
# Shared room         1160
# Name: count, dtype: int64

# %%
room_counts = df['room_type'].value_counts(normalize=True)  
# assign result to another variable

room_counts[0]
# first occurance

room_counts.iloc[2]
# use this method now, first one is depriciated
# Out:
# C:\Users\ashpi\AppData\Local\Temp\ipykernel_15032\2368504861.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   room_counts[0]
# np.float64(0.02371897108739214)

# %%
for r_cnt in room_counts:
    print(r_cnt)
# Out:
# 0.5196499407025723
# 0.45663108821003556
# 0.02371897108739214

# %% [markdown]
# categorical column neighbourhood_group analysis

# %%
df["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21669
# Brooklyn         20107
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
for i in df["neighbourhood_group"].value_counts():
    print(i)
# Out:
# 21669
# 20107
# 5666
# 1091
# 373

# %%
df["neighbourhood_group"].value_counts(normalize=True)   # will tell you percentage
# Out:
# neighbourhood_group
# Manhattan        0.443074
# Brooklyn         0.411136
# Queens           0.115855
# Bronx            0.022308
# Staten Island    0.007627
# Name: proportion, dtype: float64

# %%
for i in  df["neighbourhood_group"].value_counts(normalize=True).items():  # iterate over tuples, 
    print(i)
# Out:
# ('Manhattan', 0.44307446939025885)
# ('Brooklyn', 0.41113564797775326)
# ('Queens', 0.11585490532858954)
# ('Bronx', 0.022308101255469677)
# ('Staten Island', 0.00762687604792868)

# %%
list(df["neighbourhood_group"].value_counts(normalize=True).items())  # if you want to convert it to list of tuples
# Out:
# [('Manhattan', 0.44307446939025885),
#  ('Brooklyn', 0.41113564797775326),
#  ('Queens', 0.11585490532858954),
#  ('Bronx', 0.022308101255469677),
#  ('Staten Island', 0.00762687604792868)]

# %%
for i in df["neighbourhood_group"].value_counts(normalize=True):
    print(i)
# Out:
# 0.44307446939025885
# 0.41113564797775326
# 0.11585490532858954
# 0.022308101255469677
# 0.00762687604792868

# %%
 neighbourhood_group= df['neighbourhood_group'].drop_duplicates() 
 df['neighbourhood_group'].drop_duplicates()
# Out:
# 0           Brooklyn
# 1          Manhattan
# 46            Queens
# 169    Staten Island
# 171            Bronx
# Name: neighbourhood_group, dtype: object

# %%
neighbourhood_group[0:3]
# Out:
# 0      Brooklyn
# 1     Manhattan
# 46       Queens
# Name: neighbourhood_group, dtype: object

# %% [markdown]
# Analyzing Numerical Data Price

# %%
df['price'].describe()

df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890600e+04  4.890600e+04  48906.000000  48906.000000  48906.000000
# mean   1.901287e+07  6.760480e+07     40.728952    -73.952175    152.711324
# std    1.098557e+07  7.860866e+07      0.054529      0.046154    240.128713
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.464662e+06  7.809567e+06     40.690100    -73.983080     69.000000
# 50%    1.967545e+07  3.078463e+07     40.723080    -73.955685    106.000000
# 75%    2.915085e+07  1.074344e+08     40.763120    -73.936283    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48906.000000       48906.000000       38854.000000
# mean         7.031612          23.300454           1.373151
# std         20.512489          44.607175           1.680270
# ...
